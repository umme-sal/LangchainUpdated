# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

from langchain.chat_models import init_chat_model

model=init_chat_model("groq:llama-3.3-70b-versatile")

# %%
model.invoke("Please tell me what is AI")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)** is a broad field of computer science that focuses on creating intelligent machines capable of performing tasks that typically require human intelligence. These tasks include:\n\n1. **Learning**: AI systems can learn from data, experiences, and interactions.\n2. **Reasoning**: AI systems can draw inferences, make decisions, and solve problems.\n3. **Problem-solving**: AI systems can identify and resolve complex problems.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n\nThe primary goals of AI research are to:\n\n1. **Create intelligent machines**: Design and develop systems that can simulate human thought processes and behaviors.\n2. **Improve decision-making**: Enable machines to make informed decisions, often in real-time.\n3. **Enhance automation**: Automate tasks, reducing the need for human intervention.\n\n**Types of AI:**\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as image recognition or language translation.\n2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.\n3. **Superintelligence**: A hypothetical AI system that significantly surpasses human intelligence.\n\n**AI Applications:**\n\n1. **Virtual Assistants**: Siri, Alexa, and Google Assistant\n2. **Image and Speech Recognition**: Self-driving cars, facial recognition systems\n3. **Natural Language Processing**: Chatbots, language translation software\n4. **Predictive Analytics**: Forecasting, recommendation systems\n5. **Robotics**: Industrial automation, service robots\n\nAI has the potential to revolutionize numerous industries and aspects of our lives, from healthcare and education to transportation and entertainment. However, it also raises important questions about ethics, bias, and the future of work.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 367, 'prompt_tokens': 41, 'total_tokens': 408, 'completion_time': 0.847550493, 'completion_tokens_details': None, 'prompt_time': 0.001957534, 'prompt_tokens_details': None, 'queue_time': 0.052530881, 'total_time': 0.849508027}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f8f60-d184-7dd1-be21-3464051b7bba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 367, 'total_tokens': 408})

# %%
from langchain.messages import SystemMessage,HumanMessage
system_msg = SystemMessage("You are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API
# ====================
# ### Overview
#
# A REST (Representational State of Resource) API is an architectural style for designing networked applications. It's based on the idea of resources, which are identified by URIs, and can be manipulated using a fixed set of operations.
#
# ### Prerequisites
#
# * Programming language (e.g., Python, Java, Node.js)
# * Framework (e.g., Flask, Django, Express.js)
# * Database (e.g., MySQL, MongoDB)
#
# ### Step 1: Plan the API
#
# 1. **Define the resources**: Identify the entities that will be exposed through the API (e.g., users, products, orders).
# 2. **Determine the operations**: Decide which CRUD (Create, Read, Update, Delete) operations will be supported for each resource.
# 3. **Choose the API endpoints**: Define the URIs for each resource and operation (e.g., `/users`, `/products/{id}`, `/orders/{id}/cancel`).
#
# ### Step 2: Set up the Framework and Database
#
# 1. **Choose a framework**: Select a suitable framework for your programming language (e.g., Flask for Python, Express.js for Node.js).
# 2. **Install dependencies**: Install the required dependencies for your framework and database.
# 3. **Configure the database**: Set up your database and define the schema for your resources.
#
# ### Step 3: Implement the API Endpoints
#
# 1. **Create API endpoints**: Use your framework to create API endpoints for each resource and operation.
# 2. **Implement CRUD operations**: Write code to perform CRUD operations on your resources (e.g., create a new user, read a product, update an order).
# 3. **Handle errors and validation**: Implement error handling and validation for each endpoint.
#
# ### Step 4: Test the API
#
# 1. **Use a testing tool**: Choose a tool like Postman, cURL, or a testing framework (e.g., Pytest, Jest) to test your API.
# 2. **Test each endpoint**: Verify that each endpoint returns the expected response and handles errors correctly.
# 3. **Test for security vulnerabilities**: Test your API for common security vulnerabilities (e.g., SQL injection, cross-site scripting).
#
# ### Example Code (Python with Flask)
#
# ```python
# from flask import Flask, jsonify, request
# from flask_sqlalchemy import SQLAlchemy
#
# app = Flask(__name__)
# app.config["SQLALCHEMY_DATABASE_URI"] = "sqlite:///example.db"
# db = SQLAlchemy(app)
#
# class User(db.Model):
#     id = db.Column(db.Integer, primary_key=True)
#     name = db.Column(db.String(100), nullable=False)
#     email = db.Column(db.String(100), nullable=False, unique=True)
#
# @app.route("/users", methods=["GET"])
# def get_users():
#     users = User.query.all()
#     return jsonify([{"id": user.id, "name": user.name, "email": user.email} for user in users])
#
# @app.route("/users", methods=["POST"])
# def create_user():
#     new_user = User(name=request.json["name"], email=request.json["email"])
#     db.session.add(new_user)
#     db.session.commit()
#     return jsonify({"id": new_user.id, "name": new_user.name, "email": new_user.email}), 201
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ### Best Practices
#
# * **Use meaningful endpoint names**: Choose endpoint names that accurately describe the resource and operation.
# * **Use HTTP methods correctly**: Use the correct HTTP method for each operation (e.g., GET for reading, POST for creating).
# * **Handle errors and validation**: Implement robust error handling and validation to ensure your API is secure and reliable.
# * **Document your API**: Provide clear and concise documentation for your API, including endpoint descriptions, request and response formats, and error handling.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 50, 'output_tokens': 778, 'total_tokens': 828}
