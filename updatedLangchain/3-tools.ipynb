# %% [markdown]
# Tools

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["HUGGINGFACEHUB_API_TOKEN"]=os.getenv("HUGGINGFACEHUB_API_TOKEN")

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("groq:llama-3.3-70b-versatile")
response=model.invoke("What is quamtum computing?")
response
# Out:
# AIMessage(content="**Introduction to Quantum Computing**\n=====================================\n\nQuantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It's a new paradigm for computing that has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.\n\n**Key Concepts**\n----------------\n\n1. **Qubits**: Quantum computing uses quantum bits or qubits, which are the basic units of quantum information. Qubits are unique because they can exist in multiple states simultaneously, known as superposition.\n2. **Superposition**: Qubits can represent both 0 and 1 at the same time, allowing for parallel processing of multiple possibilities.\n3. **Entanglement**: Qubits can be entangled, meaning that the state of one qubit is dependent on the state of another qubit, even if they are separated by large distances.\n4. **Quantum gates**: Quantum gates are the quantum equivalent of logic gates in classical computing. They perform operations on qubits, such as rotation, entanglement, and measurement.\n\n**How Quantum Computing Works**\n-------------------------------\n\n1. **Quantum circuits**: Quantum algorithms are implemented using quantum circuits, which are composed of quantum gates and qubits.\n2. **Quantum algorithms**: Quantum algorithms are designed to take advantage of the unique properties of qubits and quantum gates. Examples include Shor's algorithm for factorization and Grover's algorithm for search.\n3. **Quantum measurement**: Quantum measurement is the process of extracting information from a qubit. This can be done using various techniques, such as projective measurement or weak measurement.\n\n**Advantages and Applications**\n------------------------------\n\n1. **Exponential scaling**: Quantum computing has the potential to solve certain problems exponentially faster than classical computing.\n2. **Cryptography**: Quantum computing can be used to break certain types of classical encryption, but it can also be used to create new, quantum-resistant encryption methods.\n3. **Optimization**: Quantum computing can be used to solve complex optimization problems, such as those found in logistics, finance, and energy management.\n4. **Simulation**: Quantum computing can be used to simulate complex systems, such as molecules and materials, which can lead to breakthroughs in fields like chemistry and materials science.\n\n**Current State and Future Directions**\n--------------------------------------\n\n1. **Quantum noise and error correction**: Quantum computing is prone to noise and errors, which can be mitigated using various techniques, such as quantum error correction and noise reduction.\n2. **Quantum software and programming**: Quantum software and programming languages, such as Q# and Qiskit, are being developed to make quantum computing more accessible.\n3. **Quantum hardware**: Quantum hardware, such as quantum processors and quantum simulators, are being developed to enable the implementation of quantum algorithms.\n\nIn summary, quantum computing is a new paradigm for computing that uses the principles of quantum mechanics to perform calculations and operations on data. It has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers. While there are still challenges to overcome, quantum computing is a rapidly evolving field with many exciting applications and future directions.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 651, 'prompt_tokens': 42, 'total_tokens': 693, 'completion_time': 2.012281888, 'completion_tokens_details': None, 'prompt_time': 0.007370888, 'prompt_tokens_details': None, 'queue_time': 0.318659229, 'total_time': 2.019652776}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965',  ...

# %%
from langchain.tools import tool

@tool
def get_weather(location:str)->str:
    """Get the weather of a location"""
    return f"It is sunny in {location}"

model_with_tools=model.bind_tools([get_weather])

# %%
response=model_with_tools.invoke("What is the weather in Dubai")
print(response)
for call in response.tool_calls:
    print(f"Tools: {call['name']}")
    print(f"Args: {call['args']}")
# Out:
# content='' additional_kwargs={'tool_calls': [{'id': 'je21ebw9e', 'function': {'arguments': '{"location":"Dubai"}', 'name': 'get_weather'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 218, 'total_tokens': 233, 'completion_time': 0.060167415, 'completion_tokens_details': None, 'prompt_time': 0.023410402, 'prompt_tokens_details': None, 'queue_time': 0.161185106, 'total_time': 0.083577817}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f8f48-66f5-7211-8786-0f2b45ecc129-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Dubai'}, 'id': 'je21ebw9e', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 218, 'output_tokens': 15, 'total_tokens': 233}
# Tools: get_weather
# Args: {'location': 'Dubai'}

# %% [markdown]
# Tool Execution loops
